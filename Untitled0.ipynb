# %% [markdown]
# <a href="https://colab.research.google.com/github/murata-m/mysite/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/Kaggle/
# Out:
# /content/drive/MyDrive/Kaggle

# %%
# %ls
# Out:
#  competitive-data-science-predict-future-sales.zip
# 'competitive-data-science-predict-future-sales.zip (Unzipped Files)'/
#  submission_lightgbm.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import StandardScaler
InteractiveShell.ast_node_interactivity = "all"

# %%
item_categories = pd.read_csv("competitive-data-science-predict-future-sales.zip (Unzipped Files)/item_categories.csv")
items = pd.read_csv("competitive-data-science-predict-future-sales.zip (Unzipped Files)/items.csv")
sales_train = pd.read_csv("competitive-data-science-predict-future-sales.zip (Unzipped Files)/sales_train.csv")
sample_submission = pd.read_csv("competitive-data-science-predict-future-sales.zip (Unzipped Files)/sample_submission.csv")
shops = pd.read_csv("competitive-data-science-predict-future-sales.zip (Unzipped Files)/shops.csv")
test = pd.read_csv("competitive-data-science-predict-future-sales.zip (Unzipped Files)/test.csv")

# %%
# item_categories.head()
items.head()
sales_train
sample_submission
# shops.head()
test.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]
#             ID  item_cnt_month
# 0            0             0.5
# 1            1             0.5
# 2            2             0.5
# 3            3             0.5
# 4            4             0.5
# ...        ...             ...
# 214195  214195             0.5
# 214196  214196             0.5
# 214197  214197             0.5
# 214198  214198             0.5
# 214199  214199             0.5
#
# [214200 rows x 2 columns]
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
del items['item_name']
del sales_train["date"]

# %%
# item_categories.head()
items
sales_train
# sample_submission
# shops.head()
test.head()
# Out:
#        item_id  item_category_id
# 0            0                40
# 1            1                76
# 2            2                40
# 3            3                40
# 4            4                40
# ...        ...               ...
# 22165    22165                31
# 22166    22166                54
# 22167    22167                49
# 22168    22168                62
# 22169    22169                69
#
# [22170 rows x 2 columns]
#          date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0                     0       59    22154      999.00           1.0
# 1                     0       25     2552      899.00           1.0
# 2                     0       25     2552      899.00          -1.0
# 3                     0       25     2554     1709.05           1.0
# 4                     0       25     2555     1099.00           1.0
# ...                 ...      ...      ...         ...           ...
# 2935844              33       25     7409      299.00           1.0
# 2935845              33       25     7460      299.00           1.0
# 2935846              33       25     7459      349.00           1.0
# 2935847              33       25     7440      299.00           1.0
# 2935848              33       25     7460      299.00           1.0
#
# [2935849 rows x 5 columns]
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
sales_train = sales_train.merge(items, on="item_id", how="left")
display(sales_train)
# Out:
#          date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0                     0       59    22154      999.00           1.0
# 1                     0       25     2552      899.00           1.0
# 2                     0       25     2552      899.00          -1.0
# 3                     0       25     2554     1709.05           1.0
# 4                     0       25     2555     1099.00           1.0
# ...                 ...      ...      ...         ...           ...
# 2935844              33       25     7409      299.00           1.0
# 2935845              33       25     7460      299.00           1.0
# 2935846              33       25     7459      349.00           1.0
# 2935847              33       25     7440      299.00           1.0
# 2935848              33       25     7460      299.00           1.0
#
#          item_category_id
# 0                      37
# 1                      58
# 2                      58
# 3                      58
# 4                      56
# ...                   ...
# 2935844                55
# 2935845                55
# 2935846                55
# 2935847                57
# 2935848                55
#
# [2935849 rows x 6 columns]

# %% [markdown]
# 各店舗のアイテムごとの月の売り上げ個数を計算する

# %%
sale_train_group = sales_train.groupby(["date_block_num", "shop_id", "item_id"], as_index=False)["item_cnt_day"].sum()
display(sale_train_group)
# Out:
#          date_block_num  shop_id  item_id  item_cnt_day
# 0                     0        0       32           6.0
# 1                     0        0       33           3.0
# 2                     0        0       35           1.0
# 3                     0        0       43           1.0
# 4                     0        0       51           2.0
# ...                 ...      ...      ...           ...
# 1609119              33       59    22087           6.0
# 1609120              33       59    22088           2.0
# 1609121              33       59    22091           1.0
# 1609122              33       59    22100           1.0
# 1609123              33       59    22102           1.0
#
# [1609124 rows x 4 columns]

# %% [markdown]
# 月、店舗、アイテムが同じとき一行にまとめる

# %%
del sales_train["item_cnt_day"]
sales_train = sales_train.drop_duplicates(["date_block_num","shop_id","item_id"])
display(sales_train)
# Out:
#          date_block_num  shop_id  item_id  item_price  item_category_id
# 0                     0       59    22154      999.00                37
# 1                     0       25     2552      899.00                58
# 3                     0       25     2554     1709.05                58
# 4                     0       25     2555     1099.00                56
# 5                     0       25     2564      349.00                59
# ...                 ...      ...      ...         ...               ...
# 2935840              33       25     7409      299.00                55
# 2935841              33       25     7393      349.00                55
# 2935842              33       25     7384      749.00                55
# 2935846              33       25     7459      349.00                55
# 2935847              33       25     7440      299.00                57
#
# [1609124 rows x 5 columns]

# %% [markdown]
# 月の売り上げ個数を結合する

# %%
sales_train = sale_train_group.merge(sales_train, on=["date_block_num","shop_id","item_id"], how="left")
sales_train = sales_train.rename(columns={"item_cnt_day":"item_cnt_month"})
display(sales_train)
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month  item_price  \
# 0                     0        0       32             6.0       221.0
# 1                     0        0       33             3.0       347.0
# 2                     0        0       35             1.0       247.0
# 3                     0        0       43             1.0       221.0
# 4                     0        0       51             2.0       130.0
# ...                 ...      ...      ...             ...         ...
# 1609119              33       59    22087             6.0       119.0
# 1609120              33       59    22088             2.0       119.0
# 1609121              33       59    22091             1.0       179.0
# 1609122              33       59    22100             1.0       629.0
# 1609123              33       59    22102             1.0      1250.0
#
#          item_category_id
# 0                      40
# 1                      37
# 2                      40
# 3                      40
# 4                      57
# ...                   ...
# 1609119                83
# 1609120                83
# 1609121                83
# 1609122                42
# 1609123                42
#
# [1609124 rows x 6 columns]

# %% [markdown]
# カテゴリ変数のtarget encoding テストデータにもトレインにフィットさせた値で標準化適用

# %%
def Standard(s):
  return (s-s.mean())/s.std()

date_block_num_group = sales_train.groupby("date_block_num", as_index=False)["item_cnt_month"].sum()
date_block_num_group = date_block_num_group.rename(columns={"item_cnt_month":"date_std"})
date_block_num_group["date_std"] = Standard(date_block_num_group["date_std"])
sales_train = sales_train.merge(date_block_num_group, on="date_block_num", how="left")

shop_id_group = sales_train.groupby("shop_id", as_index=False)["item_cnt_month"].sum()
shop_id_group = shop_id_group.rename(columns={"item_cnt_month":"shop_id_std"})
shop_id_group["shop_id_std"] = Standard(shop_id_group["shop_id_std"])
sales_train = sales_train.merge(shop_id_group, on="shop_id", how="left")

item_id_group = sales_train.groupby("item_id", as_index=False)["item_cnt_month"].sum()
item_id_group = item_id_group.rename(columns={"item_cnt_month":"item_id_std"})
item_id_group["item_id_std"] = Standard(item_id_group["item_id_std"])
sales_train = sales_train.merge(item_id_group, on="item_id", how="left")

item_category_id_group = sales_train.groupby("item_category_id", as_index=False)["item_cnt_month"].sum()
item_category_id_group = item_category_id_group.rename(columns={"item_cnt_month":"item_category_id_std"})
item_category_id_group["item_category_id_std"] = Standard(item_category_id_group["item_category_id_std"])
sales_train = sales_train.merge(item_category_id_group, on="item_category_id", how="left")


sales_train
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month  item_price  \
# 0                     0        0       32             6.0       221.0
# 1                     0        0       33             3.0       347.0
# 2                     0        0       35             1.0       247.0
# 3                     0        0       43             1.0       221.0
# 4                     0        0       51             2.0       130.0
# ...                 ...      ...      ...             ...         ...
# 1609119              33       59    22087             6.0       119.0
# 1609120              33       59    22088             2.0       119.0
# 1609121              33       59    22091             1.0       179.0
# 1609122              33       59    22100             1.0       629.0
# 1609123              33       59    22102             1.0      1250.0
#
#          item_category_id  date_std  shop_id_std  item_id_std  \
# 0                      40  0.849691    -0.846628     1.408781
# 1                      37  0.849691    -0.846628     0.489456
# 2                      40  0.849691    -0.846628     0.040041
# 3                      40  0.849691    -0.846628    -0.115864
# 4                      57  0.849691    -0.846628     0.050288
# ...                   ...       ...          ...          ...
# 1609119                83 -1.273691    -0.203653     2.400568
# 1609120                83 -1.273691    -0.203653     3.737102
# 1609121                83 -1.273691    -0.203653     0.750029
# 1609122                42 -1.273691    -0.203653     0.163008
# 1609123                42 -1.273691    -0.203653     1.127713
#
#          item_category_id_std
# 0                    5.916510
# 1                    1.600995
# 2                    5.916510
# 3                    5.916510
# 4                   -0.107646
# ...                       ...
# 1609119             -0.314474
# 1609120             -0.314474
# 1609121             -0.314474
# 1609122             -0.395369
# 1609123             -0.395369
#
# [1609124 rows x 10 columns]

# %% [markdown]
# trainの整理終了
# 以下テストデータに情報を付与する
# shop_idとitem_idを基準としてtestにsales_trainをマージしたいがshop_idとitem_idが同じでdate_block_numが異なる行が多くありitem_priceにばらつきがあるため月に影響を受けないitem_priceを平均で求める

# %%
mergedata_fortest = sales_train.drop("item_cnt_month", axis=1)
mergedata_fortest = mergedata_fortest.groupby(["shop_id", "item_id"], as_index=False)["item_price","item_category_id"].mean()
display(mergedata_fortest)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#         shop_id  item_id  item_price  item_category_id
# 0             0       30       265.0              40.0
# 1             0       31       434.0              37.0
# 2             0       32       221.0              40.0
# 3             0       33       347.0              37.0
# 4             0       35       247.0              40.0
# ...         ...      ...         ...               ...
# 424119       59    22154       999.0              37.0
# 424120       59    22155       149.0              37.0
# 424121       59    22162       369.0              40.0
# 424122       59    22164       724.0              37.0
# 424123       59    22167       299.0              49.0
#
# [424124 rows x 4 columns]

# %%
display(test)
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %% [markdown]
# 価格とカテゴリー情報を追加後、カテゴリ変数をターゲットエンコーディング、標準化した（lightgbmは数値の大小のみの影響だがロジスティック回帰では標準化する必要あり）値に変更

# %%
test = test.merge(mergedata_fortest, on=["shop_id","item_id"], how="left")

test = test.merge(shop_id_group, on="shop_id", how="left")
test = test.merge(item_id_group, on="item_id", how="left")
test = test.merge(item_category_id_group, on="item_category_id", how="left")

display(test)
# Out:
#             ID  shop_id  item_id   item_price  item_category_id  shop_id_std  \
# 0            0        5     5037  1749.055556              19.0    -0.311097
# 1            1        5     5320          NaN               NaN    -0.311097
# 2            2        5     5233   839.000000              19.0    -0.311097
# 3            3        5     5232   599.000000              23.0    -0.311097
# 4            4        5     5268          NaN               NaN    -0.311097
# ...        ...      ...      ...          ...               ...          ...
# 214195  214195       45    18454   179.000000              55.0    -0.326047
# 214196  214196       45    16188          NaN               NaN    -0.326047
# 214197  214197       45    15757   199.000000              55.0    -0.326047
# 214198  214198       45    19648          NaN               NaN    -0.326047
# 214199  214199       45      969   549.000000              37.0    -0.326047
#
#         item_id_std  item_category_id_std
# 0          0.807121              2.117821
# 1               NaN                   NaN
# 2          0.248646              2.117821
# 3         -0.019247              1.267081
# 4               NaN                   NaN
# ...             ...                   ...
# 214195     0.255965              3.056306
# 214196    -0.119523                   NaN
# 214197     0.148369              3.056306
# 214198    -0.081462                   NaN
# 214199     0.100061              1.600995
#
# [214200 rows x 8 columns]

# %%
test["item_price"] = test["item_price"].fillna(test["item_price"].mean())
test["item_category_id"] = test["item_category_id"].fillna(0)
test["shop_id"] = test["shop_id"].fillna(test["shop_id"].mean())
test["item_id_std"] = test["item_id_std"].fillna(test["item_id_std"].mean())
test["item_category_id_std"] = test["item_category_id_std"].fillna(test["item_category_id_std"].mean())

display(test)
# Out:
#             ID  shop_id  item_id   item_price  item_category_id  shop_id_std  \
# 0            0        5     5037  1749.055556              19.0    -0.311097
# 1            1        5     5320   992.829110               0.0    -0.311097
# 2            2        5     5233   839.000000              19.0    -0.311097
# 3            3        5     5232   599.000000              23.0    -0.311097
# 4            4        5     5268   992.829110               0.0    -0.311097
# ...        ...      ...      ...          ...               ...          ...
# 214195  214195       45    18454   179.000000              55.0    -0.326047
# 214196  214196       45    16188   992.829110               0.0    -0.326047
# 214197  214197       45    15757   199.000000              55.0    -0.326047
# 214198  214198       45    19648   992.829110               0.0    -0.326047
# 214199  214199       45      969   549.000000              37.0    -0.326047
#
#         item_id_std  item_category_id_std
# 0          0.807121              2.117821
# 1          0.174712              1.956008
# 2          0.248646              2.117821
# 3         -0.019247              1.267081
# 4          0.174712              1.956008
# ...             ...                   ...
# 214195     0.255965              3.056306
# 214196    -0.119523              1.956008
# 214197     0.148369              3.056306
# 214198    -0.081462              1.956008
# 214199     0.100061              1.600995
#
# [214200 rows x 8 columns]

# %%
test["item_price"].isnull().sum()
# Out:
# 0

# %%
del sales_train["date_block_num"]
del sales_train["shop_id"]
del sales_train["item_id"]
del sales_train["item_category_id"]
del test["shop_id"]
del test["item_id"]
del test["item_category_id"]

# %%
sales_train_y = sales_train["item_cnt_month"]
sales_train_x = sales_train.drop("item_cnt_month",axis=1)
display(sales_train_x)
display(sales_train_y)
# Out:
#          item_price  date_std  shop_id_std  item_id_std  item_category_id_std
# 0             221.0  0.849691    -0.846628     1.408781              5.916510
# 1             347.0  0.849691    -0.846628     0.489456              1.600995
# 2             247.0  0.849691    -0.846628     0.040041              5.916510
# 3             221.0  0.849691    -0.846628    -0.115864              5.916510
# 4             130.0  0.849691    -0.846628     0.050288             -0.107646
# ...             ...       ...          ...          ...                   ...
# 1609119       119.0 -1.273691    -0.203653     2.400568             -0.314474
# 1609120       119.0 -1.273691    -0.203653     3.737102             -0.314474
# 1609121       179.0 -1.273691    -0.203653     0.750029             -0.314474
# 1609122       629.0 -1.273691    -0.203653     0.163008             -0.395369
# 1609123      1250.0 -1.273691    -0.203653     1.127713             -0.395369
#
# [1609124 rows x 5 columns]
# 0          6.0
# 1          3.0
# 2          1.0
# 3          1.0
# 4          2.0
#           ...
# 1609119    6.0
# 1609120    2.0
# 1609121    1.0
# 1609122    1.0
# 1609123    1.0
# Name: item_cnt_month, Length: 1609124, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_valid,y_train,y_valid=train_test_split(sales_train_x,sales_train_y,test_size = 0.3, random_state = 0)
categorical_features = ["date_std","shop_id_std","item_id_std","item_price","item_category_id_std"]

# %%
import lightgbm as lgb

lgb_train = lgb.Dataset(X_train,y_train,categorical_feature = categorical_features)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train, categorical_feature=categorical_features)

params = {"objective":"regression",
          "metric":"rmse"}

model = lgb.train(params,lgb_train,valid_sets=[lgb_train, lgb_eval],verbose_eval=100, num_boost_round=10000,early_stopping_rounds=50)
y_pred_lgb = model.predict(test, num_iteration=model.best_iteration)
display(y_pred_lgb)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 6.03083	valid_1's rmse: 6.2844
# Early stopping, best iteration is:
# [78]	training's rmse: 6.11751	valid_1's rmse: 6.27985
# array([2.9162052 , 1.5247656 , 1.71392771, ..., 1.19346655, 1.5247656 ,
#        1.5247656 ])

# %%
lgb.plot_importance(model,figsize=(12,6))
plt.show()

# %% [markdown]
# ロジスティック回帰

# %%
# from sklearn.linear_model import LogisticRegression
# clf = LogisticRegression(penalty='l2', solver="sag", random_state=0)
# clf.fit(X_train, y_train)
# y_pred_clf = clf.predict(test)
# display(y_pred_clf)

# %% [markdown]
# データまとめ

# %%
sub = sample_submission
sub["item_cnt_month_lgb"] = y_pred_lgb
# sub["item_cnt_month_clf"] = y_pred_clf
# sub["item_cnt_month"] = sub["item_cnt_month_lgb","item_cnt_month_clf"].mean()
sub.loc[:,"item_cnt_month"]+=0.5
sub["item_cnt_month"] = sub["item_cnt_month"].astype("int")
sub.to_csv("submission_lightgbm.csv", index=False)

sub.head()
# Out:
#    ID  item_cnt_month  item_cnt_month_lgb
# 0   0               1            2.916205
# 1   1               1            1.524766
# 2   2               1            1.713928
# 3   3               1            1.524766
# 4   4               1           39.470424
